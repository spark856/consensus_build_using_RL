# %%
# Start virtual display
# %matplotlib inline
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1024, 768))
display.start()
import os
os.environ["DISPLAY"] = ":" + str(display.display) + "." + str(display.screen)
#from ddpg import run,test
from DQN import opt_test


#data = [2,2,3,4,0,744*1,"outside_aug_2019"] # 消費電力、満足度、bad人数、外気温、割引率 、学習回数
data = [3,3,2,3,"outside_aug_2018","gdemand0"]
opt_test(*data)
